# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("INR=X.csv")
print(data.head())

plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Day")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

print(data.corr())
sns.heatmap(data.corr())
plt.show()

x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("INR=X.csv")
print(data.head())

plt.figure(figsize=(10, 5))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Day")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

print(data.corr())
sns.heatmap(data.corr())
plt.show()

x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2021-09-08  73.390900  73.868401  73.266502  73.390404  73.390404       0
# 1  2021-09-09  73.795799  73.862000  73.489502  73.789001  73.789001       0
# 2  2021-09-10  73.545303  73.576797  73.373802  73.538002  73.538002       0
# 3  2021-09-13  73.524300  73.776802  73.516998  73.524300  73.524300       0
# 4  2021-09-14  73.540802  73.721802  73.514999  73.540802  73.540802       0
#                Open      High       Low     Close  Adj Close  Volume
# Open       1.000000  0.996810  0.996924  0.999849   0.999849     NaN
# High       0.996810  1.000000  0.996584  0.996788   0.996788     NaN
# Low        0.996924  0.996584  1.000000  0.997003   0.997003     NaN
# Close      0.999849  0.996788  0.997003  1.000000   1.000000     NaN
# Adj Close  0.999849  0.996788  0.997003  1.000000   1.000000     NaN
# Volume          NaN       NaN       NaN       NaN        NaN     NaN
#    Predicted Rate
# 0       79.882896
# 1       79.194801
# 2       77.818703
# 3       76.524101
# 4       75.391296
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2021-09-08  73.390900  73.868401  73.266502  73.390404  73.390404       0
# 1  2021-09-09  73.795799  73.862000  73.489502  73.789001  73.789001       0
# 2  2021-09-10  73.545303  73.576797  73.373802  73.538002  73.538002       0
# 3  2021-09-13  73.524300  73.776802  73.516998  73.524300  73.524300       0
# 4  2021-09-14  73.540802  73.721802  73.514999  73.540802  73.540802       0
#                Open      High       Low     Close  Adj Close  Volume
# Open       1.000000  0.996810  0.996924  0.999849   0.999849     NaN
# High       0.996810  1.000000  0.996584  0.996788   0.996788     NaN
# Low        0.996924  0.996584  1.000000  0.997003   0.997003     NaN
# Close      0.999849  0.996788  0.997003  1.000000   1.000000     NaN
# Adj Close  0.999849  0.996788  0.997003  1.000000   1.000000     NaN
# Volume          NaN       NaN       NaN       NaN        NaN     NaN
#    Predicted Rate
# 0       79.882896
# 1       79.331398
# 2       77.818703
# 3       76.524101
# 4       75.391296
